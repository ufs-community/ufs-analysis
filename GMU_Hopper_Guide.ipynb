# %% [markdown]
# <h1>Intro to GMU Hopper & ufs-analysis</h1>
# <h3>Aug. 2026</h3>

# %% [markdown]
# This notebook introduces new users to George Mason University's (GMU) HOPPER computing platform and gets them started using the `ufs-community/ufs-analysis` package.  If you are unfamiliar with Git, please refer to the README titled `Updating Github repositories, a Hopper-specific introduction` located here: https://github.com/cristianastan2/large-scale-dynamics.  Here, we assume that you will be using Python during your Hopper sessions.<br><br>

# %% [markdown]
# <h2>GMU Hopper Dashboard</h2>

# %% [markdown]
# Open the GMU Hopper dashboard here: https://ondemand.orc.gmu.edu/pun/sys/dashboard<br>
# This is where you manage Hopper sessions.  <br><br>
# For daily use, the most convenient way to use Python on Hopper is by launching a Jupyter server.  Our first concern in this tutorial, however, is creating the proper Python environment to use with ```ufs-analysis```.<br><br>
# ***For all Python-packaging work, it is strongly recommended that you use HOPPER Shell Access sessions.***<br>
# In the top navigation panel, click the `Clusters` dropdown and then select `>_ HOPPER Shell Access`.  This will launch a Hopper session in a new window.  Using this shell session, we will install all necessary Python packages into our profile.<br>
# <br>

# %% [markdown]
# <h2>Miniforge</h2>

# %% [markdown]
# First, we must install the right Python package manager (Miniforge).<br>
# Instructions for doing so can be found here: https://wiki.orc.gmu.edu/mkdocs/Conda_Environments_on_Hopper/<br>
#
# The two important instructions in that guide are Download Miniforge and then Install Miniforge.  For this part, make sure you are in your HOME directory, `/home/<your_username>/`.  Type the `pwd` command to make sure. Then,<br>
# Download Miniforge:<br>
# ```$ wget https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh```
#
# Install Miniforge into your HOME directory:<br>
# ```$ bash Miniforge3-Linux-x86_64.sh -b -p $HOME/miniforge```
#
#
# And lastly, source Miniforge:<br>
# ```$ source $HOME/miniforge3/bin/activate```<br>
# Note that you must source Miniforge every time you start a new Hopper session.  Sourcing Miniforge will give you the `conda` commands to use later.
# <br><br>

# %% [markdown]
# <h2>Clone repository</h2>

# %% [markdown]
# Now we can start working with the `ufs-analysis` repository.  Clone the repository into your HOME directory:<br>
# ```$ git clone git@github.com:ufs-community/ufs-analysis.git```<br>
#
# Move into the `ufs-analysis` directory:<br>
# ```$ cd ufs-analysis```
# <br><br>

# %% [markdown]
# <h2>Create new Python environment</h2>

# %% [markdown]
# Inside the `ufs-analysis` directory you'll see a file called `environment.yml`.  This file defines all the required packages and their versions needed to run `ufs-analysis` codes on a Linux-based computing platform (which Hopper is).<br><br>
#
# We can create a new `Conda` environment via Miniforge by issuing the following command:<br>
# ```$ conda env create -f environment.yml```<br>
#
# This will take a few minutes to complete.  After this is done, there will be a new Conda environment named `ufs_py311`.<br>
# See here:<br>
# ```$ conda env list```
#
# ```
# # conda environments:
# #
# # ufs_py311              /home/<your_username>/miniforge2/envs/ufs_py311
# ```
#
# Now you can activate the environment:<br>
# ```$ conda activate ufs_py311```<br>
#
# The active environment will prepend your terminal handle with something like this:<br>
# ```(ufs_py311) [<your_username>@hopper2 ~]$```<br>
# Note that you will have to activate your environment for every HOPPER session.
# <br><br>

# %% [markdown]
# <h2>Create Python kernel</h2>

# %% [markdown]
# To make use of your special Python environment in an interactive Jupyter notebook, you must first create a Python kernel for your environment.  The commands necessary to do so were already installed as part of the `ufs_py311` environment!<br><br>
# To create a Python Kernel, make sure the environment you want to kernelize (`ufs_py311`) is active, then run:<br>
# ```$ ipython kernel install --name "ufs_py311" --user```<br>
#
# To verify that your kernel was correctly installed, run:<br>
# ```jupyter kernelspec list```<br>
#
# ```
# Available kernels:
#   python3          /home/<your_username>/miniforge2/envs/ufs_py311/share/jupyter/kernels/python3
#   ufs_py311        /home/<your_username>/.local/share/jupyter/kernels/ufs_py311
# ```
# <br>

# %% [markdown]
# <h2>Interactive Jupyter Sessions</h2>

# %% [markdown]
# Now that the Python kernel is created, we can begin working with our `ufs-analysis` code interactively via Jupyter.<br>Close the `>_ HOPPER Shell Access` window and navigate back to the Hopper Dashboard.  Under `Servers` click on a Jupyter application instance (any one will do).  This will open a page with configurable options for your Jupyter session.  Under `Extra Arguments for Jupyter:` make sure you have something like `--notebook-dir=/home/<your_username>/`.  Then, based on your needs, you can configure `Time limit in hours:`, `Number of Cores:`, and `Memory GBs/core:`. You can probably always set `8 GBs/core`, but for time limit and number of cores, please be mindful not to reserve too many more resources than you need.  If you finish working before your session expires, then please manually close the session to free up computing resources for other users.<br><br>
#
# Once you have decided on the parameters for your Jupyter session, click `Launch`.  A `Launcher` window will appear with buttons for opening a `Terminal` and `Jupyter` notebooks.  When you launch a Jupyter notebook, there is an indicator in the top-right of the screen for the Python kernel.  Make sure it is set to our newly created kernel, `ufs_py311`.
# <br><br>

# %% [markdown]
# Et voila, you are now ready to harness the power of `ufs-analysis` on Hopper.

# %% [markdown]
# Refer to `ufs-analysis/tutorial.ipynb` for further instruction!
